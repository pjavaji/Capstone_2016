# %% [markdown]
# ### Create Visualization Data Time Series

# %%
import pandas as pd

# Read in the grouped data from Neo4j (see workbook for ResultsGroupedByCandidateTopic)

df = pd.read_csv("./hourly_results.csv")
df.head()
# Out:
#           day  hour Trump Clinton Sanders Cruz Rubio topic  frequency  users  \
# 0  2015_10_11    19   neu     NaN     NaN  NaN   NaN   NaN          1      1
# 1  2015_10_11     1   NaN     neu     NaN  NaN   NaN   NaN          1      1
# 2  2015_10_11     1   NaN     neg     NaN  NaN   NaN   NaN          1      1
# 3  2015_10_11    18   NaN     neu     NaN  NaN   NaN   NaN          1      1
# 4  2015_10_11     5   NaN     pos     NaN  NaN   NaN   NaN          1      1
#
#            mints          maxts
# 0  1352229456000  1352229456000
# 1  1360374148000  1360374148000
# 2  1362445434000  1362445434000
# 3  1363112126000  1363112126000
# 4  1372224919000  1372224919000

# %%
from datetime import datetime

# Append the day and hour adjusted to EST (UTC-5)
# convert ms to s for python
def converttime(ts):
    ts_adjust = (ts/1000) - (3600*5)
    dt = datetime.utcfromtimestamp(ts_adjust)
    return dt

def convertday(ts):
    dt = converttime(ts)
    return dt.day

def convertmonth(ts):
    dt = converttime(ts)
    return dt.month

def convertyear(ts):
    dt = converttime(ts)
    return dt.year

def converthour(ts):
    dt = converttime(ts)
    return dt.hour

# When an item is retweeted, we keep a copy of the original tweet (based on retweet_status).
# This copy might be from prior to our day.  we need to remove this data from the final result.
def keepRetweetedItem(partition, ts):
    ts_adjust = ts / 1000
    dt = datetime.utcfromtimestamp(ts_adjust)
    year, month, day = partition.split('_')
    return ((int(year)==dt.year) and (int(month)==dt.month) and (int(day)==dt.day))

print converttime(1444607999000)
print convertday(1444607999000)
print convertmonth(1444607999000)
print convertyear(1444607999000)
print converthour(1444607999000)
print keepRetweetedItem('2015_10_11',1444607999000)
print keepRetweetedItem('2015_10_11',1428188930000)
# Out:
# 2015-10-11 18:59:59
# 11
# 10
# 2015
# 18
# True
# False

# %%
df['x_day'] = df['mints'].apply(convertday)
df['month'] = df['mints'].apply(convertmonth)
df['year'] = df['mints'].apply(convertyear)
df['hour'] = df['mints'].apply(converthour)
df.head()
# Out:
#           day  hour Trump Clinton Sanders Cruz Rubio topic  frequency  users  \
# 0  2015_10_11    14   neu     NaN     NaN  NaN   NaN   NaN          1      1
# 1  2015_10_11    20   NaN     neu     NaN  NaN   NaN   NaN          1      1
# 2  2015_10_11    20   NaN     neg     NaN  NaN   NaN   NaN          1      1
# 3  2015_10_11    13   NaN     neu     NaN  NaN   NaN   NaN          1      1
# 4  2015_10_11     0   NaN     pos     NaN  NaN   NaN   NaN          1      1
#
#            mints          maxts  x_day  month  year
# 0  1352229456000  1352229456000      6     11  2012
# 1  1360374148000  1360374148000      8      2  2013
# 2  1362445434000  1362445434000      4      3  2013
# 3  1363112126000  1363112126000     12      3  2013
# 4  1372224919000  1372224919000     26      6  2013

# %%
#filter out retweets from prior days
df = df[df.apply(lambda x: keepRetweetedItem(x['day'],x['mints']), axis=1)]

# %%
df.head()
# Out:
#             day  hour Trump Clinton Sanders Cruz Rubio               topic  \
# 934  2015_10_11    19   NaN     NaN     NaN  NaN   NaN               obama
# 935  2015_10_11    19   NaN     neu     NaN  NaN   NaN  black lives matter
# 936  2015_10_11    19   NaN     neu     NaN  NaN   NaN                 NaN
# 937  2015_10_11    19   neu     NaN     NaN  NaN   NaN                 NaN
# 938  2015_10_11    19   pos     NaN     NaN  NaN   NaN                 NaN
#
#      frequency  users          mints          maxts  x_day  month  year
# 934         13      1  1444522379000  1444522379000     10     10  2015
# 935         11      2  1444522724000  1444522804000     10     10  2015
# 936         10      3  1444522402000  1444524909000     10     10  2015
# 937          9      5  1444521727000  1444524664000     10     10  2015
# 938          4      3  1444521809000  1444523107000     10     10  2015

# %%
#unpivot data for candidates
df2 = pd.melt(df, id_vars=['x_day','month','year','hour','topic','frequency','mints'], \
    value_vars=['Trump','Clinton','Sanders','Cruz','Rubio'], \
    var_name='candidate', value_name='sentiment')

# %%
df2.head()
# Out:
#    x_day  month  year  hour               topic  frequency          mints  \
# 0     10     10  2015    19               obama         13  1444522379000
# 1     10     10  2015    19  black lives matter         11  1444522724000
# 2     10     10  2015    19                 NaN         10  1444522402000
# 3     10     10  2015    19                 NaN          9  1444521727000
# 4     10     10  2015    19                 NaN          4  1444521809000
#
#   candidate sentiment
# 0     Trump       NaN
# 1     Trump       NaN
# 2     Trump       NaN
# 3     Trump       neu
# 4     Trump       pos

# %%
#drop rows where sentiment is not available
df2.dropna(subset=['sentiment'], inplace=True)

# %%
df2.head()
# Out:
#     x_day  month  year  hour topic  frequency          mints candidate  \
# 3      10     10  2015    19   NaN          9  1444521727000     Trump
# 4      10     10  2015    19   NaN          4  1444521809000     Trump
# 18     10     10  2015    19   NaN          1  1444524483000     Trump
# 24     10     10  2015    20   NaN          7  1444525694000     Trump
# 34     10     10  2015    20   NaN          1  1444528680000     Trump
#
#    sentiment
# 3        neu
# 4        pos
# 18       neu
# 24       neu
# 34       pos

# %%
df2.sort(['year','month','x_day','hour','candidate','topic','sentiment'], inplace=True)

# %%
df2.to_csv('scrubbed_results2.csv', index=False)

# %%
#number should be a little higher than original file because some tweets have multiple candidate references.
print df2['frequency'].sum()
# Out:
# 100763325

# %%
print df['frequency'].sum()
# Out:
# 86051876

# %%
df3 = df2.groupby()
