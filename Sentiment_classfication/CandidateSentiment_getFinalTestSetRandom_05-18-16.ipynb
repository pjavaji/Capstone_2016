# %%
# Purpose:  Pull a random sample of tweets to use as final validation set for candidate-sentiment classifiers.
#           This will produce 10 per partition per candidate, for 400 per candidate, and 2000 total tweets. 
# Author:  Carol Sniegoski, adapted from Debbie Hofman
# Date:  May 18, 2016
# Course:  MAS DSE Capstone, Spring 2016

# %%
candidates = ['Trump','Clinton','Sanders','Cruz','Rubio']
print candidates
# Out:
# ['Trump', 'Clinton', 'Sanders', 'Cruz', 'Rubio']

# %%
# Define queries for obtaining tweets that mention each candidate.
# The queries defined here get random samples. They do not exclude mentions of other candidates.

# This approach is very time-consuming. It may be doing a giant sort on everything.
# example:
# MATCH (t:Tweet_2016_3_1)
# WHERE EXISTS(t.mentions_Sanders) 
# WITH t, rand() as random
# RETURN t.text ORDER BY random LIMIT 10

# This approach is not entirely random, but it is quick, and sort of random.
# MATCH (t:Tweet_2016_3_1)
# WHERE EXISTS(t.mentions_Sanders) 
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10

queries = {}

queries['Sanders'] = """MATCH (t:Tweet_{0})
WHERE EXISTS(t.mentions_Sanders) 
WITH t.text as tweetText
WHERE rand()<.001
RETURN tweetText LIMIT 10
"""

queries['Clinton'] = """MATCH (t:Tweet_{0})
WHERE EXISTS(t.mentions_Clinton) 
WITH t.text as tweetText
WHERE rand()<.001
RETURN tweetText LIMIT 10
"""

queries['Trump'] = """MATCH (t:Tweet_{0})
WHERE EXISTS(t.mentions_Trump) 
WITH t.text as tweetText
WHERE rand()<.0001
RETURN tweetText LIMIT 10
"""

queries['Rubio'] = """MATCH (t:Tweet_{0})
WHERE EXISTS(t.mentions_Rubio) 
WITH t.text as tweetText
WHERE rand()<.001
RETURN tweetText LIMIT 10
"""

queries['Cruz'] = """MATCH (t:Tweet_{0})
WHERE EXISTS(t.mentions_Cruz) 
WITH t.text as tweetText
WHERE rand()<.001
RETURN tweetText LIMIT 10
"""

print 'done'
# Out:
# done

# %%
partitions = ['2015_10_11', '2015_10_12', '2015_10_13', '2015_10_14', '2015_10_15',\
              '2016_1_26', '2016_1_27', '2016_1_28', '2016_1_29', '2016_1_30', '2016_2_3', \
              '2016_2_4', '2016_2_5', '2016_2_6', '2016_2_7', '2016_2_8', '2016_2_9', '2016_2_10',\
              '2016_2_11', '2016_2_12', '2016_2_13', '2016_2_14', '2016_2_15', \
              '2016_2_23', '2016_2_24', '2016_2_25', '2016_2_26', '2016_3_1', '2016_3_2',\
             '2016_3_3', '2016_3_4', '2016_3_5', '2016_3_6', '2016_3_7', '2016_3_8', '2016_3_9',\
             '2016_3_10', '2016_3_11']

# partitions = ['2016_2_24', '2016_2_25', '2016_2_26', '2016_3_1', '2016_3_2',\
#              '2016_3_3', '2016_3_4', '2016_3_5', '2016_3_6', '2016_3_7', '2016_3_8', '2016_3_9',\
#              '2016_3_10', '2016_3_11']

print 'done'
# Out:
# done

# %%
from neo4j.v1 import GraphDatabase, basic_auth
import time
import csv

#driver = GraphDatabase.driver("bolt://sauce5.sdsc.edu", auth=basic_auth("neo4j", "lajolla"))
print 'opening driver...'
driver = GraphDatabase.driver("bolt://sauce5.sdsc.edu", auth=basic_auth("neo4j", "lajolla"))
#driver = GraphDatabase.driver("bolt://127.0.0.1")
print 'after opening driver...'
# Out:
# opening driver...
# after opening driver...

# %%
# Locate data output directory
# %ls ../data/candidatesentiment/
# Out:
# candidatesentiment_fromDebbie_05-14-16.csv  output/
# candidatesentiment_fromDebbie_05-17-16.csv  sentimentsamples_random_05-18-16.csv

# %%
# Create output filename.
prefix = "../data/candidatesentiment/"
filename = "candidatesentiment_validationSet_random_05-19-16.csv"
outfile = prefix + filename
print outfile
# Out:
# ../data/candidatesentiment/candidatesentiment_validationSet_random_05-19-16.csv

# %%
candidates = ['Trump', 'Clinton', 'Sanders', 'Rubio', 'Cruz']
print candidates
# Out:
# ['Trump', 'Clinton', 'Sanders', 'Rubio', 'Cruz']

# %%
# Get data from neo4j and write to file.

#with open('sentimentsamples.csv', 'wb') as csvfile:
with open(outfile, 'wb') as csvfile:
    tweetwriter = csv.writer(csvfile)
    total_start = time.time()
    
    for partition in partitions:
    #for partition in ['2016_2_12']:

        print "PARTITION:", partition
        partition_start = time.time()
        
        for candidate in candidates:
            print
            print "CANDIDATE:", candidate

            start = time.time()

            query = queries[candidate].format(partition)
            print query

            session = driver.session()
            result = session.run(query)

            for record in result:
                #print partition, candidate, record[0]
                #tweetwriter.writerow([partition,candidate,'pos','supporter',record[0].encode("utf-8")])
                tweetwriter.writerow([partition, candidate, record[0].encode("utf-8")])

            session.close()

            end = time.time()
        print
        print "Time for partition " + partition + ": " + str(time.time() - partition_start)
    print "Total time:" + str(time.time() - total_start)
    
print 'done'
# Out:
# PARTITION: 2015_10_11
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2015_10_11)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2015_10_11)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2015_10_11)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2015_10_11)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2015_10_11)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2015_10_11: 2.93518304825
# PARTITION: 2015_10_12
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2015_10_12)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2015_10_12)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2015_10_12)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2015_10_12)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2015_10_12)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2015_10_12: 23.5902738571
# PARTITION: 2015_10_13
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2015_10_13)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2015_10_13)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2015_10_13)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2015_10_13)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2015_10_13)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2015_10_13: 33.4510498047
# PARTITION: 2015_10_14
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2015_10_14)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2015_10_14)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2015_10_14)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2015_10_14)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2015_10_14)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2015_10_14: 76.2868368626
# PARTITION: 2015_10_15
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2015_10_15)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2015_10_15)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2015_10_15)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2015_10_15)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2015_10_15)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2015_10_15: 11.5498487949
# PARTITION: 2016_1_26
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_1_26)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_1_26)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_1_26)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_1_26)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_1_26)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_1_26: 31.2281970978
# PARTITION: 2016_1_27
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_1_27)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_1_27)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_1_27)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_1_27)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_1_27)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_1_27: 17.7354030609
# PARTITION: 2016_1_28
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_1_28)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_1_28)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_1_28)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_1_28)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_1_28)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_1_28: 16.4857890606
# PARTITION: 2016_1_29
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_1_29)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_1_29)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_1_29)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_1_29)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_1_29)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_1_29: 12.9763700962
# PARTITION: 2016_1_30
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_1_30)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_1_30)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_1_30)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_1_30)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_1_30)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_1_30: 17.4344680309
# PARTITION: 2016_2_3
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_3)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_3)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_3)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_3)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_3)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_3: 21.50334692
# PARTITION: 2016_2_4
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_4)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_4)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_4)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_4)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_4)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_4: 16.4374380112
# PARTITION: 2016_2_5
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_5)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_5)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_5)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_5)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_5)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_5: 54.8308138847
# PARTITION: 2016_2_6
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_6)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_6)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_6)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_6)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_6)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_6: 39.0141119957
# PARTITION: 2016_2_7
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_7)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_7)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_7)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_7)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_7)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_7: 27.6442270279
# PARTITION: 2016_2_8
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_8)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_8)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_8)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_8)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_8)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_8: 37.1196951866
# PARTITION: 2016_2_9
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_9)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_9)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_9)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_9)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_9)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_9: 53.2002620697
# PARTITION: 2016_2_10
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_10)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_10)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_10)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_10)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_10)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_10: 104.23101306
# PARTITION: 2016_2_11
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_11)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_11)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_11)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_11)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_11)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_11: 71.5781910419
# PARTITION: 2016_2_12
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_12)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_12)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_12)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_12)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_12)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_12: 3.78462600708
# PARTITION: 2016_2_13
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_13)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_13)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_13)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_13)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_13)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_13: 17.5583610535
# PARTITION: 2016_2_14
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_14)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_14)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_14)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_14)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_14)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_14: 37.0196430683
# PARTITION: 2016_2_15
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_15)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_15)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_15)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_15)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_15)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_15: 27.0228490829
# PARTITION: 2016_2_23
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_23)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_23)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_23)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_23)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_23)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_23: 25.5432350636
# PARTITION: 2016_2_24
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_24)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_24)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_24)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_24)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_24)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_24: 37.9189729691
# PARTITION: 2016_2_25
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_25)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_25)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_25)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_25)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_25)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_25: 55.3238759041
# PARTITION: 2016_2_26
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_2_26)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_2_26)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_2_26)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_2_26)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_2_26)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_2_26: 47.8965201378
# PARTITION: 2016_3_1
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_1)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_1)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_1)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_1)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_1)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_1: 21.490363121
# PARTITION: 2016_3_2
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_2)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_2)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_2)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_2)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_2)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_2: 23.2195541859
# PARTITION: 2016_3_3
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_3)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_3)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_3)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_3)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_3)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_3: 13.6982440948
# PARTITION: 2016_3_4
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_4)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_4)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_4)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_4)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_4)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_4: 6.27956795692
# PARTITION: 2016_3_5
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_5)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_5)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_5)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_5)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_5)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_5: 5.35798311234
# PARTITION: 2016_3_6
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_6)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_6)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_6)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_6)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_6)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_6: 4.93198204041
# PARTITION: 2016_3_7
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_7)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_7)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_7)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_7)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_7)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_7: 8.80639004707
# PARTITION: 2016_3_8
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_8)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_8)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_8)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_8)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_8)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_8: 9.19616293907
# PARTITION: 2016_3_9
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_9)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_9)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_9)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_9)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_9)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_9: 6.11221194267
# PARTITION: 2016_3_10
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_10)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_10)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_10)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_10)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_10)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_10: 16.8587989807
# PARTITION: 2016_3_11
#
# CANDIDATE: Trump
# MATCH (t:Tweet_2016_3_11)
# WHERE EXISTS(t.mentions_Trump)
# WITH t.text as tweetText
# WHERE rand()<.0001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Clinton
# MATCH (t:Tweet_2016_3_11)
# WHERE EXISTS(t.mentions_Clinton)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Sanders
# MATCH (t:Tweet_2016_3_11)
# WHERE EXISTS(t.mentions_Sanders)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Rubio
# MATCH (t:Tweet_2016_3_11)
# WHERE EXISTS(t.mentions_Rubio)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# CANDIDATE: Cruz
# MATCH (t:Tweet_2016_3_11)
# WHERE EXISTS(t.mentions_Cruz)
# WITH t.text as tweetText
# WHERE rand()<.001
# RETURN tweetText LIMIT 10
#
#
# Time for partition 2016_3_11: 4.14990401268
# Total time:1041.40479183
# done
