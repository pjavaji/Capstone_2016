# %%
hourly_query="""match (t:Tweet_{0}) \
where exists(t.mentions_Trump) \
or exists(t.mentions_Clinton) \
or exists(t.mentions_Sanders) \
or exists(t.mentions_Cruz) \
or exists(t.mentions_Rubio) \
or exists(t.mentions_Kasich) \
or exists(t.mentions_Omally) \
or exists(t.mentions_Carson) \
or exists(t.mentions_Fiorina) \
or exists(t.mentions_Huckabee) \
or exists(t.mentions_Paul) \
or exists(t.mentions_Christie) \
or exists(t.mentions_Bush) \
or exists(t.topic) \
WITH t.mentions_Trump as Trump, \
t.mentions_Clinton as Clinton, \
t.mentions_Sanders as Sanders, \
t.mentions_Cruz as Cruz, \
t.mentions_Rubio as Rubio, \
t.mentions_Kasich as Kasich, \
t.mentions_Omally as Omally, \
t.mentions_Christie as Christie, \
t.mentions_Paul as Paul, \
t.mentions_Carson as Carson, \
t.mentions_Fiorina as Fiorina, \
t.mentions_Huckabee as Huckabee, \
t.mentions_Bush as Bush, \
t.topic as topic, \
(toInt(t.timestamp_int) / 3600000) as hour_group, count(t) as frequency, \
MIN(t.timestamp_int) as mints \
RETURN mints, Trump, Clinton, Sanders, Cruz, Rubio, \
Kasich, Omally, Christie, Paul, Carson, Fiorina, Huckabee, Bush, topic, frequency \
order by frequency desc"""

hourly_header=['year', 'month', 'day', 'hour', 'mints',\
               'Trump','Clinton','Sanders','Cruz','Rubio',\
               'Kasich', 'Omally', 'Christie', 'Paul', 'Carson', 'Fiorina', 'Huckabee', 'Bush',\
               'topic','frequency']

# %%
partitions = ['2015_10_11', '2015_10_12', '2015_10_13', '2015_10_14', '2015_10_15',\
              '2016_1_26', '2016_1_27', '2016_1_28', '2016_1_29', '2016_1_30', '2016_2_2', '2016_2_3', \
              '2016_2_4', '2016_2_5', '2016_2_6', '2016_2_7', '2016_2_8', '2016_2_9', '2016_2_10',\
              '2016_2_11', '2016_2_12', '2016_2_13', '2016_2_14', '2016_2_15', \
              '2016_2_23', '2016_2_24', '2016_2_25', '2016_2_26', '2016_2_27', \
              '2016_3_1', '2016_3_2','2016_3_3', '2016_3_4', '2016_3_5', '2016_3_6', '2016_3_7', \
              '2016_3_8', '2016_3_9', '2016_3_10', '2016_3_11']

# %%
from datetime import datetime

# Append the day and hour adjusted to EST (UTC-5)
# convert ms to s for python
def converttime(ts):
    ts_adjust = (ts/1000) - (3600*5)
    dt = datetime.utcfromtimestamp(ts_adjust)
    return dt.year, dt.month, dt.day, dt.hour

# When an item is retweeted, we keep a copy of the original tweet (based on retweet_status).
# This copy might be from prior to our day.  we need to remove this data from the final result.
def keepRetweetedItem(partition, ts):
    ts_adjust = ts / 1000
    dt = datetime.utcfromtimestamp(ts_adjust)
    year, month, day = partition.split('_')
    return ((int(year)==dt.year) and (int(month)==dt.month) and (int(day)==dt.day))

print converttime(1444607999000)
print keepRetweetedItem('2015_10_11',1444607999000)
print keepRetweetedItem('2015_10_11',1428188930000)
# Out:
# (2015, 10, 11, 18)
# True
# False

# %%
import time
import logging
import csv
from neo4jreader import neo4j_reader

#set up logging
logger = logging.getLogger('ResultsGroupedByCandidateTopic2')
hdlr = logging.FileHandler('./results2_tagging.log')
formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
hdlr.setFormatter(formatter)
logger.addHandler(hdlr) 
logger.setLevel(logging.INFO)

reader = neo4j_reader('local',logger)

with open('hourly_results.csv', 'wb') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(hourly_header)
    
    for partition in partitions:

        start = time.time()

        formatted_query = hourly_query.format(partition)
        #print formatted_query

        for record in reader.runquery(formatted_query):
            outrecord = []
            for i in range(len(record)):
                outrecord.append(record[i])

            mints = int(outrecord[0])
                
            #some of the neutral items were labeled true instead of neu, correct these.
            #TODO: correct these in the database.
            for n in range(1,14):
                if ("true" in str(outrecord[n]).lower()):
                    outrecord[n]="neu"

            #convert time from UTC to EST and add day/hour information to output
            year, month, day, hour = converttime(mints)
            outrecord = [year, month, day, hour] + outrecord

            csvwriter.writerow(outrecord)  

        print partition, time.time() - start
# Out:
# 2015_10_11 1.88331580162
# 2015_10_12 10.3455529213
# 2015_10_13 13.5996718407
# 2015_10_14 24.5881140232
# 2015_10_15 3.78546714783
# 2016_1_26 21.4532818794
# 2016_1_27 23.9675559998
# 2016_1_28 22.2140920162
# 2016_1_29 25.5507919788
# 2016_1_30 19.1482348442
# 2016_2_2 34.2794377804
# 2016_2_3 24.9862120152
# 2016_2_4 24.7666580677
# 2016_2_5 25.0177669525
# 2016_2_6 19.1715829372
# 2016_2_7 27.1885039806
# 2016_2_8 20.0513401031
# 2016_2_9 24.7409489155
# 2016_2_10 32.201346159
# 2016_2_11 23.5436930656
# 2016_2_12 26.7075150013
# 2016_2_13 20.6301300526
# 2016_2_14 27.6933429241
# 2016_2_15 20.5767540932
# 2016_2_23 25.4139909744
# 2016_2_24 32.607874155
# 2016_2_25 30.0303099155
# 2016_2_26 36.9787230492
# 2016_2_27 31.3748011589
# 2016_3_1 36.8130772114
# 2016_3_2 44.0164160728
# 2016_3_3 38.6327681541
# 2016_3_4 39.6288151741
# 2016_3_5 31.7046039104
# 2016_3_6 32.2526547909
# 2016_3_7 22.782335043
# 2016_3_8 30.5166270733
# 2016_3_9 33.8757359982
# 2016_3_10 28.2182650566
# 2016_3_11 4.74613690376

# %%
import pandas as pd

#verify counts by hour
df = pd.read_csv('hourly_results.csv')
df
# Out:
#          year  month  day  hour          mints Trump Clinton Sanders Cruz  \
# 0        2015     10   11    18  1444604401832   neg     NaN     NaN  NaN
# 1        2015     10   11    18  1444604400152   NaN     neu     NaN  NaN
# 2        2015     10   11    18  1444604401312   neu     NaN     NaN  NaN
# 3        2015     10   11    17  1444600800000   neu     NaN     NaN  NaN
# 4        2015     10   11    17  1444600811000   NaN     neu     NaN  NaN
# 5        2015     10   11    18  1444604400679   NaN     NaN     neu  NaN
# 6        2015     10   11    18  1444604403653   pos     NaN     NaN  NaN
# 7        2015     10   11    17  1444600816000   NaN     NaN     neu  NaN
# 8        2015     10   11    18  1444604402717   NaN     neg     NaN  NaN
# 9        2015     10   11    18  1444604400625   NaN     NaN     NaN  NaN
# 10       2015     10   11    17  1444600973000   NaN     NaN     NaN  NaN
# 11       2015     10   11    17  1444600814000   pos     NaN     NaN  NaN
# 12       2015     10   11    17  1444600817000   NaN     NaN     NaN  NaN
# 13       2015     10   11    17  1444600843000   NaN     neg     NaN  NaN
# 14       2015     10   11    17  1444600807000   neg     NaN     NaN  NaN
# 15       2015     10   11    18  1444604403392   NaN     pos     NaN  NaN
# 16       2015     10   11    18  1444604407125   NaN     NaN     pos  NaN
# 17       2015     10   11    18  1444604407807   NaN     NaN     neg  NaN
# 18       2015     10   11    17  1444600810000   NaN     pos     NaN  NaN
# 19       2015     10   11    17  1444600877000   NaN     NaN     pos  NaN
# 20       2015     10   11    17  1444601057000   NaN     NaN     neg  NaN
# 21       2015     10   11    18  1444604406914   NaN     NaN     NaN  neu
# 22       2015     10   11    17  1444601087000   NaN     NaN     NaN  neu
# 23       2015     10   11    18  1444604402707   NaN     NaN     NaN  NaN
# 24       2015     10   11    18  1444604403941   NaN     NaN     NaN  pos
# 25       2015     10   11    18  1444604411933   NaN     neu     neu  NaN
# 26       2015     10   11    17  1444600992000   NaN     NaN     NaN  pos
# 27       2015     10   11    18  1444604403811   NaN     NaN     NaN  NaN
# 28       2015     10   11    18  1444604479343   neu     NaN     NaN  neu
# 29       2015     10   11    17  1444601433000   NaN     neu     neu  NaN
# ...       ...    ...  ...   ...            ...   ...     ...     ...  ...
# 1307816  2016      3   10     6  1457609880000   NaN     neu     NaN  NaN
# 1307817  2016      3    8    21  1457488841000   pos     NaN     NaN  NaN
# 1307818  2016      1   22    14  1453491686000   NaN     pos     neu  NaN
# 1307819  2016      2   16    20  1455671479000   NaN     NaN     NaN  NaN
# 1307820  2016      3   10    10  1457622911000   pos     NaN     NaN  NaN
# 1307821  2016      2   28    17  1456697066000   NaN     neu     NaN  NaN
# 1307822  2016      3   10    19  1457654657260   NaN     neg     neg  NaN
# 1307823  2016      3    8    10  1457451044000   NaN     neg     NaN  NaN
# 1307824  2016      2    7    22  1454901613000   pos     NaN     NaN  NaN
# 1307825  2016      3   10    16  1457647181000   NaN     NaN     NaN  pos
# 1307826  2016      3   10    12  1457630134000   NaN     NaN     neu  NaN
# 1307827  2016      3    9    22  1457580479000   NaN     neg     NaN  NaN
# 1307828  2016      3   10    17  1457648118000   NaN     NaN     NaN  neg
# 1307829  2016      3    7    11  1457366559000   neg     NaN     NaN  neu
# 1307830  2016      3   10    15  1457642388000   NaN     pos     neg  NaN
# 1307831  2016      3   10     9  1457621365000   neu     NaN     NaN  neu
# 1307832  2016      3   10    19  1457657675298   pos     NaN     NaN  neg
# 1307833  2015     12    6    18  1449445301000   neu     NaN     NaN  NaN
# 1307834  2016      3   10    11  1457626308000   NaN     NaN     neu  NaN
# 1307835  2016      3   10    21  1457661667105   neu     NaN     NaN  neu
# 1307836  2015     11   12    21  1447380503000   neg     NaN     NaN  NaN
# 1307837  2016      3   10     1  1457590201000   pos     neg     NaN  NaN
# 1307838  2016      3    7    13  1457377106000   pos     NaN     NaN  NaN
# 1307839  2016      3   10    10  1457623843000   NaN     NaN     NaN  NaN
# 1307840  2016      1   22    11  1453480299000   NaN     NaN     NaN  NaN
# 1307841  2016      3    4    16  1457128514000   neu     neu     NaN  NaN
# 1307842  2016      3    9    20  1457572764000   NaN     neg     pos  NaN
# 1307843  2016      3   10    20  1457660657703   pos     NaN     NaN  NaN
# 1307844  2016      3   10    16  1457645149000   neu     neg     NaN  neu
# 1307845  2016      3   10    21  1457661662311   NaN     NaN     NaN  pos
#
#         Rubio Kasich Omally Christie  Paul Carson Fiorina Huckabee Bush  \
# 0         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 2         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 3         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 4         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 5         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 6         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 7         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 8         NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 9         NaN    NaN    NaN      NaN   NaN    neu     NaN      NaN  NaN
# 10        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  neu
# 11        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 12        NaN    NaN    NaN      NaN   NaN    neu     NaN      NaN  NaN
# 13        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 14        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 15        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 16        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 17        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 18        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 19        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 20        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 21        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 22        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 23        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  neu
# 24        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 25        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 26        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 27        neu    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 28        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 29        NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# ...       ...    ...    ...      ...   ...    ...     ...      ...  ...
# 1307816   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307817   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307818   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307819   neu    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307820   NaN    neu    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307821   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307822   neg    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307823   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307824   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307825   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  neu
# 1307826   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307827   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307828   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307829   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307830   NaN    neu    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307831   NaN    NaN    NaN      NaN   NaN    NaN     neu      NaN  NaN
# 1307832   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307833   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307834   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307835   pos    neu    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307836   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307837   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307838   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307839   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307840   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307841   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307842   NaN    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307843   neg    NaN    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307844   NaN    neu    NaN      NaN   NaN    NaN     NaN      NaN  NaN
# 1307845   NaN    NaN    NaN      NaN   NaN    neu     NaN      NaN  NaN
#
#                                         topic  frequency
# 0                                         NaN       6566
# 1                                         NaN       3791
# 2                                         NaN       3353
# 3                                         NaN       2292
# 4                                         NaN       1842
# 5                                         NaN       1532
# 6                                         NaN       1248
# 7                                         NaN       1067
# 8                                         NaN       1048
# 9                                         NaN       1015
# 10                                        NaN        938
# 11                                        NaN        803
# 12                                        NaN        717
# 13                                        NaN        670
# 14                                        NaN        668
# 15                                        NaN        663
# 16                                        NaN        628
# 17                                        NaN        464
# 18                                        NaN        441
# 19                                        NaN        402
# 20                                        NaN        385
# 21                                        NaN        335
# 22                                        NaN        318
# 23                                        NaN        243
# 24                                        NaN        215
# 25                                        NaN        158
# 26                                        NaN        150
# 27                                        NaN        110
# 28                                        NaN        109
# 29                                        NaN         93
# ...                                       ...        ...
# 1307816                            healthcare          1
# 1307817                                   cnn          1
# 1307818                                   NaN          1
# 1307819                                   NaN          1
# 1307820                           immigration          1
# 1307821                                   NaN          1
# 1307822                                   NaN          1
# 1307823  women's issues (not abortion though)          1
# 1307824                                   NaN          1
# 1307825                              religion          1
# 1307826                             socialism          1
# 1307827                           immigration          1
# 1307828                              abortion          1
# 1307829                                   NaN          1
# 1307830                                   NaN          1
# 1307831                                   NaN          1
# 1307832                fox news or moderators          1
# 1307833                                   NaN          1
# 1307834                                israel          1
# 1307835                                   NaN          1
# 1307836                                   NaN          1
# 1307837                                   NaN          1
# 1307838                                israel          1
# 1307839                                  iran          1
# 1307840                       social security          1
# 1307841                                   NaN          1
# 1307842                             socialism          1
# 1307843                                israel          1
# 1307844                                   NaN          1
# 1307845                                   NaN          1
#
# [1307846 rows x 20 columns]

# %%
df_filtered = df[['year','month','day','topic','frequency']].dropna(subset=['topic'])
print df_filtered.head()

df2 = df_filtered['frequency'].groupby([df_filtered['year'],df_filtered['month'],df_filtered['day']]).sum().reset_index()
df2.head()
# Out:
#      year  month  day               topic  frequency
# 50   2015     10   11            abortion         31
# 72   2015     10   11            benghazi         21
# 75   2015     10   11            abortion         20
# 85   2015     10   11  black lives matter         18
# 111  2015     10   11            benghazi         13
#    year  month  day  frequency
# 0  2006      3   21          1
# 1  2006      3   30          1
# 2  2006      9    8          1
# 3  2008      2    9          1
# 4  2008      2   21          1

# %%
total = df2['frequency'].sum()
print total

# with throwaway
# print total + 479103 #9172444
# Out:
# 8930876

# %%
# replace NaN with 'none' otherwise the unpivot will exclude rows where anything is NaN

# %%
#add extra columns to support total counts for topics and sentiment
df['count_topic']=df['topic']

df['count_sentiment']=-((df['Trump'].isnull()) & (df['Clinton'].isnull()) & (df['Sanders'].isnull()) &\
                       (df['Cruz'].isnull()) & (df['Rubio'].isnull()) & (df['Kasich'].isnull()) & (df['Omally'].isnull()) &\
                        (df['Christie'].isnull()) & (df['Paul'].isnull()) & (df['Carson'].isnull()) &  \
                        (df['Fiorina'].isnull()) &  (df['Huckabee'].isnull()) & (df['Bush'].isnull()))
df.reset_index(inplace=True)

# %%
#unpivot the data

df5 = pd.melt(df, id_vars=['year','month','day','hour','topic','frequency'], \
    value_vars=['count_topic','count_sentiment'], \
    var_name='candidate_or_topic', value_name='sentiment_or_topic')
df5

#value_vars=['Trump','Clinton','Sanders','Cruz','Rubio','count_topic','count_sentiment'], \
# Out:
#          year  month  day  hour                                 topic  \
# 0        2015     10   11    18                                   NaN
# 1        2015     10   11    18                                   NaN
# 2        2015     10   11    18                                   NaN
# 3        2015     10   11    17                                   NaN
# 4        2015     10   11    17                                   NaN
# 5        2015     10   11    18                                   NaN
# 6        2015     10   11    18                                   NaN
# 7        2015     10   11    17                                   NaN
# 8        2015     10   11    18                                   NaN
# 9        2015     10   11    18                                   NaN
# 10       2015     10   11    17                                   NaN
# 11       2015     10   11    17                                   NaN
# 12       2015     10   11    17                                   NaN
# 13       2015     10   11    17                                   NaN
# 14       2015     10   11    17                                   NaN
# 15       2015     10   11    18                                   NaN
# 16       2015     10   11    18                                   NaN
# 17       2015     10   11    18                                   NaN
# 18       2015     10   11    17                                   NaN
# 19       2015     10   11    17                                   NaN
# 20       2015     10   11    17                                   NaN
# 21       2015     10   11    18                                   NaN
# 22       2015     10   11    17                                   NaN
# 23       2015     10   11    18                                   NaN
# 24       2015     10   11    18                                   NaN
# 25       2015     10   11    18                                   NaN
# 26       2015     10   11    17                                   NaN
# 27       2015     10   11    18                                   NaN
# 28       2015     10   11    18                                   NaN
# 29       2015     10   11    17                                   NaN
# ...       ...    ...  ...   ...                                   ...
# 2615662  2016      3   10     6                            healthcare
# 2615663  2016      3    8    21                                   cnn
# 2615664  2016      1   22    14                                   NaN
# 2615665  2016      2   16    20                                   NaN
# 2615666  2016      3   10    10                           immigration
# 2615667  2016      2   28    17                                   NaN
# 2615668  2016      3   10    19                                   NaN
# 2615669  2016      3    8    10  women's issues (not abortion though)
# 2615670  2016      2    7    22                                   NaN
# 2615671  2016      3   10    16                              religion
# 2615672  2016      3   10    12                             socialism
# 2615673  2016      3    9    22                           immigration
# 2615674  2016      3   10    17                              abortion
# 2615675  2016      3    7    11                                   NaN
# 2615676  2016      3   10    15                                   NaN
# 2615677  2016      3   10     9                                   NaN
# 2615678  2016      3   10    19                fox news or moderators
# 2615679  2015     12    6    18                                   NaN
# 2615680  2016      3   10    11                                israel
# 2615681  2016      3   10    21                                   NaN
# 2615682  2015     11   12    21                                   NaN
# 2615683  2016      3   10     1                                   NaN
# 2615684  2016      3    7    13                                israel
# 2615685  2016      3   10    10                                  iran
# 2615686  2016      1   22    11                       social security
# 2615687  2016      3    4    16                                   NaN
# 2615688  2016      3    9    20                             socialism
# 2615689  2016      3   10    20                                israel
# 2615690  2016      3   10    16                                   NaN
# 2615691  2016      3   10    21                                   NaN
#
#          frequency candidate_or_topic sentiment_or_topic
# 0             6566        count_topic                NaN
# 1             3791        count_topic                NaN
# 2             3353        count_topic                NaN
# 3             2292        count_topic                NaN
# 4             1842        count_topic                NaN
# 5             1532        count_topic                NaN
# 6             1248        count_topic                NaN
# 7             1067        count_topic                NaN
# 8             1048        count_topic                NaN
# 9             1015        count_topic                NaN
# 10             938        count_topic                NaN
# 11             803        count_topic                NaN
# 12             717        count_topic                NaN
# 13             670        count_topic                NaN
# 14             668        count_topic                NaN
# 15             663        count_topic                NaN
# 16             628        count_topic                NaN
# 17             464        count_topic                NaN
# 18             441        count_topic                NaN
# 19             402        count_topic                NaN
# 20             385        count_topic                NaN
# 21             335        count_topic                NaN
# 22             318        count_topic                NaN
# 23             243        count_topic                NaN
# 24             215        count_topic                NaN
# 25             158        count_topic                NaN
# 26             150        count_topic                NaN
# 27             110        count_topic                NaN
# 28             109        count_topic                NaN
# 29              93        count_topic                NaN
# ...            ...                ...                ...
# 2615662          1    count_sentiment               True
# 2615663          1    count_sentiment               True
# 2615664          1    count_sentiment               True
# 2615665          1    count_sentiment               True
# 2615666          1    count_sentiment               True
# 2615667          1    count_sentiment               True
# 2615668          1    count_sentiment               True
# 2615669          1    count_sentiment               True
# 2615670          1    count_sentiment               True
# 2615671          1    count_sentiment               True
# 2615672          1    count_sentiment               True
# 2615673          1    count_sentiment               True
# 2615674          1    count_sentiment               True
# 2615675          1    count_sentiment               True
# 2615676          1    count_sentiment               True
# 2615677          1    count_sentiment               True
# 2615678          1    count_sentiment               True
# 2615679          1    count_sentiment               True
# 2615680          1    count_sentiment               True
# 2615681          1    count_sentiment               True
# 2615682          1    count_sentiment               True
# 2615683          1    count_sentiment               True
# 2615684          1    count_sentiment               True
# 2615685          1    count_sentiment              False
# 2615686          1    count_sentiment              False
# 2615687          1    count_sentiment               True
# 2615688          1    count_sentiment               True
# 2615689          1    count_sentiment               True
# 2615690          1    count_sentiment               True
# 2615691          1    count_sentiment               True
#
# [2615692 rows x 8 columns]

# %%
df5a = df5.dropna(subset=['sentiment_or_topic'])
print df5a.head()

df5a[df5a['candidate_or_topic']=='count_topic']
# Out:
#      year  month  day  hour               topic  frequency candidate_or_topic  \
# 50   2015     10   11    18            abortion         31        count_topic
# 72   2015     10   11    18            benghazi         21        count_topic
# 75   2015     10   11    17            abortion         20        count_topic
# 85   2015     10   11    18  black lives matter         18        count_topic
# 111  2015     10   11    17            benghazi         13        count_topic
#
#      sentiment_or_topic
# 50             abortion
# 72             benghazi
# 75             abortion
# 85   black lives matter
# 111            benghazi
#          year  month  day  hour                                 topic  \
# 50       2015     10   11    18                              abortion
# 72       2015     10   11    18                              benghazi
# 75       2015     10   11    17                              abortion
# 85       2015     10   11    18                    black lives matter
# 111      2015     10   11    17                              benghazi
# 112      2015     10   11    18  women's issues (not abortion though)
# 114      2015     10   11    17                           billclinton
# 121      2015     10   11    17                              benghazi
# 125      2015     10   11    18                                 obama
# 127      2015     10   11    17                    black lives matter
# 128      2015     10   11    17                           billclinton
# 131      2015     10   11    18                              benghazi
# 138      2015     10   11    15                              abortion
# 139      2015     10   11    18                           gun control
# 141      2015     10   11    17  women's issues (not abortion though)
# 149      2015     10   11    17                                   cnn
# 151      2015     10   11    17                                  isis
# 154      2015     10   11    16  women's issues (not abortion though)
# 158      2015     10   11    18                                   cnn
# 160      2015     10   11    17                           gun control
# 164      2015     10   11    18                           billclinton
# 179      2015     10   11    16                              abortion
# 188      2015     10   11    17                           gun control
# 199      2015     10   11    18                                  isis
# 206      2015     10   11    18                                 obama
# 208      2015     10   11    12                              benghazi
# 210      2015     10   11    16                    black lives matter
# 212      2015     10   11    18                    black lives matter
# 215      2015     10   11    15                                  isis
# 217      2015     10   11    18                           billclinton
# ...       ...    ...  ...   ...                                   ...
# 1307768  2016      3   10    16  women's issues (not abortion though)
# 1307779  2016      3   10    13                         racial issues
# 1307782  2016      3    9    21                fox news or moderators
# 1307783  2016      3    9    16                             socialism
# 1307784  2016      3   10    18                           immigration
# 1307785  2016      3   10    17                       social security
# 1307790  2016      3   10    20                fox news or moderators
# 1307793  2016      3   10    21                                   cnn
# 1307796  2016      3   10    15                                   cnn
# 1307797  2016      3   10    19                           immigration
# 1307799  2016      3    8    13                           immigration
# 1307804  2016      3    5    21                         racial issues
# 1307805  2016      3   10     0  women's issues (not abortion though)
# 1307811  2016      3   10    21                           immigration
# 1307815  2016      3   10    20                              religion
# 1307816  2016      3   10     6                            healthcare
# 1307817  2016      3    8    21                                   cnn
# 1307820  2016      3   10    10                           immigration
# 1307823  2016      3    8    10  women's issues (not abortion though)
# 1307825  2016      3   10    16                              religion
# 1307826  2016      3   10    12                             socialism
# 1307827  2016      3    9    22                           immigration
# 1307828  2016      3   10    17                              abortion
# 1307832  2016      3   10    19                fox news or moderators
# 1307834  2016      3   10    11                                israel
# 1307838  2016      3    7    13                                israel
# 1307839  2016      3   10    10                                  iran
# 1307840  2016      1   22    11                       social security
# 1307842  2016      3    9    20                             socialism
# 1307843  2016      3   10    20                                israel
#
#          frequency candidate_or_topic                    sentiment_or_topic
# 50              31        count_topic                              abortion
# 72              21        count_topic                              benghazi
# 75              20        count_topic                              abortion
# 85              18        count_topic                    black lives matter
# 111             13        count_topic                              benghazi
# 112             13        count_topic  women's issues (not abortion though)
# 114             12        count_topic                           billclinton
# 121             11        count_topic                              benghazi
# 125             11        count_topic                                 obama
# 127             11        count_topic                    black lives matter
# 128             11        count_topic                           billclinton
# 131             11        count_topic                              benghazi
# 138             10        count_topic                              abortion
# 139             10        count_topic                           gun control
# 141             10        count_topic  women's issues (not abortion though)
# 149              9        count_topic                                   cnn
# 151              9        count_topic                                  isis
# 154              8        count_topic  women's issues (not abortion though)
# 158              8        count_topic                                   cnn
# 160              8        count_topic                           gun control
# 164              8        count_topic                           billclinton
# 179              7        count_topic                              abortion
# 188              7        count_topic                           gun control
# 199              6        count_topic                                  isis
# 206              6        count_topic                                 obama
# 208              6        count_topic                              benghazi
# 210              6        count_topic                    black lives matter
# 212              6        count_topic                    black lives matter
# 215              6        count_topic                                  isis
# 217              5        count_topic                           billclinton
# ...            ...                ...                                   ...
# 1307768          1        count_topic  women's issues (not abortion though)
# 1307779          1        count_topic                         racial issues
# 1307782          1        count_topic                fox news or moderators
# 1307783          1        count_topic                             socialism
# 1307784          1        count_topic                           immigration
# 1307785          1        count_topic                       social security
# 1307790          1        count_topic                fox news or moderators
# 1307793          1        count_topic                                   cnn
# 1307796          1        count_topic                                   cnn
# 1307797          1        count_topic                           immigration
# 1307799          1        count_topic                           immigration
# 1307804          1        count_topic                         racial issues
# 1307805          1        count_topic  women's issues (not abortion though)
# 1307811          1        count_topic                           immigration
# 1307815          1        count_topic                              religion
# 1307816          1        count_topic                            healthcare
# 1307817          1        count_topic                                   cnn
# 1307820          1        count_topic                           immigration
# 1307823          1        count_topic  women's issues (not abortion though)
# 1307825          1        count_topic                              religion
# 1307826          1        count_topic                             socialism
# 1307827          1        count_topic                           immigration
# 1307828          1        count_topic                              abortion
# 1307832          1        count_topic                fox news or moderators
# 1307834          1        count_topic                                israel
# 1307838          1        count_topic                                israel
# 1307839          1        count_topic                                  iran
# 1307840          1        count_topic                       social security
# 1307842          1        count_topic                             socialism
# 1307843          1        count_topic                                israel
#
# [647313 rows x 8 columns]

# %%
df5a.to_csv('hourly_results_unpivoted.csv')

# %%
df5a[df5a['candidate_or_topic']=='count_sentiment']['frequency'].sum()
# Out:
# 64812597
