# %% [markdown]
# ### This script groups in Neo4j by time period, what candidate a user supports in their tweets (tagged from a sentiment model), and topic.  Used in visualizations.

# %%
hourly_query="""
match (t:Tweet_{0})<-[:POSTS]-(u:User_{0}) \
where exists(t.mentions_Trump) \
or exists(t.mentions_Clinton) \
or exists(t.mentions_Sanders) \
or exists(t.mentions_Cruz) \
or exists(t.mentions_Rubio) \
or exists(t.topic)
WITH t.mentions_Trump as Trump, \
t.mentions_Clinton as Clinton, \
t.mentions_Sanders as Sanders, \
t.mentions_Cruz as Cruz, \
t.mentions_Rubio as Rubio, \
t.topic as topic, \
u.supports as supports, (toInt(t.timestamp_int) / 3600000) as hour_group, count(t) as frequency, \
MIN(t.timestamp_int) as mints \
RETURN supports, mints, Trump, Clinton, Sanders, Cruz, Rubio, \
topic, frequency"""

hourly_header=['year', 'month', 'day', 'hour', 'supports', 'mints',\
               'Trump','Clinton','Sanders','Cruz','Rubio',\
               'topic','frequency']
#hourly_header=['supports','mints','Trump','Clinton','Sanders','Cruz','Rubio','topic','frequency']

candidates = ['Trump','Clinton','Sanders','Cruz','Rubio']

# %%
partitions = ['2015_10_11', '2015_10_12', '2015_10_13', '2015_10_14', '2015_10_15',\
              '2016_1_26', '2016_1_27', '2016_1_28', '2016_1_29', '2016_1_30', '2016_2_2', '2016_2_3', \
              '2016_2_4', '2016_2_5', '2016_2_6', '2016_2_7', '2016_2_8', '2016_2_9', '2016_2_10',\
              '2016_2_11', '2016_2_12', '2016_2_13', '2016_2_14', '2016_2_15', \
              '2016_2_23', '2016_2_24', '2016_2_25', '2016_2_26', '2016_2_27', \
              '2016_3_1', '2016_3_2','2016_3_3', '2016_3_4', '2016_3_5', '2016_3_6', '2016_3_7', \
              '2016_3_8', '2016_3_9', '2016_3_10', '2016_3_11']
#partitions = ['2016_1_26']

# %%
from datetime import datetime

# Append the day and hour adjusted to EST (UTC-5)
# convert ms to s for python
def converttime(ts):
    ts_adjust = (ts/1000) - (3600*5)
    dt = datetime.utcfromtimestamp(ts_adjust)
    return dt.year, dt.month, dt.day, dt.hour

# When an item is retweeted, we keep a copy of the original tweet (based on retweet_status).
# This copy might be from prior to our day.  we need to remove this data from the final result.
def keepRetweetedItem(partition, ts):
    ts_adjust = ts / 1000
    dt = datetime.utcfromtimestamp(ts_adjust)
    year, month, day = partition.split('_')
    return ((int(year)==dt.year) and (int(month)==dt.month) and (int(day)==dt.day))

print converttime(1444607999000)
print keepRetweetedItem('2015_10_11',1444607999000)
print keepRetweetedItem('2015_10_11',1428188930000)
# Out:
# (2015, 10, 11, 18)
# True
# False

# %%
import time
import logging
import csv
from neo4jreader import neo4j_reader

#set up logging
logger = logging.getLogger('ResultsGroupedBySupports')
hdlr = logging.FileHandler('./supports_results_tagging.log')
formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
hdlr.setFormatter(formatter)
logger.addHandler(hdlr) 
logger.setLevel(logging.INFO)

reader = neo4j_reader('local',logger)

with open('hourly_supports_results.csv', 'wb') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(hourly_header)
    
    #throwaway=0
    
    for partition in partitions:

        start = time.time()

        formatted_query = hourly_query.format(partition)
        #print formatted_query

        for record in reader.runquery(formatted_query):
            outrecord = []
            for i in range(len(record)):
                outrecord.append(record[i])

            mints = int(outrecord[1])

            #if (keepRetweetedItem(partition, mints)):

            #some of the neutral items were labeled true instead of neu, correct these.
            #TODO: correct these in the database.
            for n in range(2,7):
                if ("true" in str(outrecord[n]).lower()):
                    outrecord[n]="neu"

            #convert time from UTC to EST and add day/hour information to output
            year, month, day, hour = converttime(mints)
            outrecord = [year, month, day, hour] + outrecord

            csvwriter.writerow(outrecord)  

#             else:
#                 throwaway = throwaway + 1


    print partition, time.time() - start
        
    #print throwaway
# Out:
# 2016_3_11 3.66286706924

# %%
import pandas as pd

#verify counts by day
df = pd.read_csv('hourly_supports_results.csv')
df.head()
# Out:
#    year  month  day  hour supports          mints Trump Clinton Sanders Cruz  \
# 0  2015     10   11    18     Cruz  1444607097494   neu     NaN     NaN  NaN
# 1  2015     10   11    12      NaN  1444583547000   NaN     NaN     neg  NaN
# 2  2015      9   16    14      NaN  1442433130000   neu     NaN     NaN  NaN
# 3  2015     10   10    20      NaN  1444528053000   neg     NaN     NaN  NaN
# 4  2015      9    4    20      NaN  1441416798000   neu     NaN     NaN  NaN
#
#   Rubio topic  frequency
# 0   neg   NaN          1
# 1   NaN   NaN          2
# 2   NaN   NaN          1
# 3   NaN   NaN          1
# 4   NaN   NaN          1

# %%
df3a = df[['year', 'month', 'day', 'hour','supports', \
               'Trump','Clinton','Sanders','Cruz','Rubio',\
               'topic','frequency']]

# %%
df['frequency'].sum()
# Out:
# 63019564

# %%
(df[(df['year']==2016) & (df['month']==1) & (df['day']==26)])

# %%
#Cleanup any values of "true"

df3a.replace('True','neu', inplace=True)
# Out:
# /Users/debbiehofman/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df3 = df3a.reset_index()
df3.fillna('none',inplace=True)
df3
# Out:
#            index  year  month  day  hour supports Trump Clinton Sanders  Cruz  \
# 0              0  2015     10   11    18     Cruz   neu    none    none  none
# 1              1  2015     10   11    12     none  none    none     neg  none
# 2              2  2015      9   16    14     none   neu    none    none  none
# 3              3  2015     10   10    20     none   neg    none    none  none
# 4              4  2015      9    4    20     none   neu    none    none  none
# 5              5  2015     10    9    14    Trump   neu    none    none  none
# 6              6  2015     10   11    17  Clinton  none     pos     neu  none
# 7              7  2015     10   11    18     none  none    none    none  none
# 8              8  2015     10   10    10     none  none    none     neu  none
# 9              9  2015     10   11    17  Sanders  none    none     neg  none
# 10            10  2015     10   11    18  Sanders  none    none     neu  none
# 11            11  2015     10   11    12     Cruz  none    none    none  none
# 12            12  2015     10   11    18     none   neu    none    none  none
# 13            13  2015     10   10    15     none  none    none    none  none
# 14            14  2015     10   11    12  Clinton  none     neg    none  none
# 15            15  2015     10   11    17     none  none    none    none   pos
# 16            16  2015     10    6     9     none   pos    none    none  none
# 17            17  2015     10   11    18  Clinton  none    none    none  none
# 18            18  2015     10   11    16  Clinton  none     neu    none  none
# 19            19  2015     10   11    15     Cruz  none    none     neg  none
# 20            20  2015     10    3    19    Trump   neu    none    none  none
# 21            21  2015     10   11    11     none  none    none    none  none
# 22            22  2015     10   11    17    Rubio  none     pos     neg  none
# 23            23  2015     10    9    13    Trump  none    none    none  none
# 24            24  2015     10   10     0     none  none    none     neu  none
# 25            25  2015      9   28    10     none  none     neu     neu  none
# 26            26  2015     10   11    15    Trump  none     neu    none  none
# 27            27  2015     10    9    16     none  none    none    none   neu
# 28            28  2015     10   11    18  Sanders  none    none     pos  none
# 29            29  2015     10   11     8     none   neu    none    none  none
# ...          ...   ...    ...  ...   ...      ...   ...     ...     ...   ...
# 2192565  2192565  2016      3    7    15     none   neg    none    none  none
# 2192566  2192566  2016      3    9    22     none  none     neg    none  none
# 2192567  2192567  2016      3   10    18     none  none    none    none   pos
# 2192568  2192568  2016      3   10     9     none   neg     neg    none  none
# 2192569  2192569  2016      3   10    19     none   neu     neu     neu  none
# 2192570  2192570  2016      3   10    21     none  none     neu    none  none
# 2192571  2192571  2016      3   10    12     none  none     neg    none  none
# 2192572  2192572  2016      3   10    19     none   pos     pos    none  none
# 2192573  2192573  2016      3   10     9     none   neu    none    none  none
# 2192574  2192574  2016      3   10    20     none  none    none    none   neu
# 2192575  2192575  2016      3   10    20     none  none     neu    none  none
# 2192576  2192576  2016      3    1     2     none  none    none    none   pos
# 2192577  2192577  2016      3   10    19     none   neu    none    none  none
# 2192578  2192578  2016      3    8    14     none  none    none    none  none
# 2192579  2192579  2016      3   10    14     none  none     neu    none  none
# 2192580  2192580  2016      3   10     6     none  none    none    none   neu
# 2192581  2192581  2016      3    9    11     none   pos    none    none  none
# 2192582  2192582  2016      3    7     7     none  none     neg    none  none
# 2192583  2192583  2016      3   10    15     none  none    none     neu  none
# 2192584  2192584  2016      3   10    20     none  none     pos     pos  none
# 2192585  2192585  2016      3    9    21     none   neu     pos    none  none
# 2192586  2192586  2016      3   10    20     none  none     neg    none  none
# 2192587  2192587  2016      3    8    23     none  none    none    none   neu
# 2192588  2192588  2016      3    9    22     none  none     neu     pos  none
# 2192589  2192589  2016      3   10     0     none   neu    none    none  none
# 2192590  2192590  2016      3   10    15     none  none     neg     neg  none
# 2192591  2192591  2016      3   10     7     none   pos    none    none  none
# 2192592  2192592  2016      3   10    19     none   pos     neg    none  none
# 2192593  2192593  2016      1   27     2     none   pos    none    none  none
# 2192594  2192594  2016      2   22    17     none  none     neg    none  none
#
#         Rubio                            topic  frequency
# 0         neg                             none          1
# 1        none                             none          2
# 2        none                             none          1
# 3        none                             none          1
# 4        none                             none          1
# 5        none                             none          3
# 6        none                             none          8
# 7        none                 jobs and economy          1
# 8        none                             none          1
# 9        none                             none         30
# 10       none  healthcare (including medicare)          1
# 11        neu                             none          1
# 12       none                             none       2491
# 13       none                         benghazi          1
# 14       none                      billclinton          1
# 15        neu                             none          1
# 16       none                             none          1
# 17        neu                             none          2
# 18       none                             none         10
# 19       none                             none          1
# 20       none                         veterans          1
# 21       none                         benghazi          2
# 22       none                             none          1
# 23       none                         abortion          1
# 24       none                             none          1
# 25       none                             none          1
# 26       none                             none          1
# 27       none                             none          1
# 28       none                           israel          1
# 29       none                             none          2
# ...       ...                              ...        ...
# 2192565  none                             none          1
# 2192566  none                   clinton emails          1
# 2192567  none                             none         64
# 2192568  none                             none          1
# 2192569  none                             none         40
# 2192570  none                      immigration          1
# 2192571   neu                             none          1
# 2192572  none                             none          2
# 2192573  none                              gop          1
# 2192574  none                       healthcare          8
# 2192575  none                 jobs and economy         26
# 2192576  none                             none          1
# 2192577  none                         religion         49
# 2192578   neu                             none          1
# 2192579  none                             none         45
# 2192580  none                     conservatism          1
# 2192581  none                             none         10
# 2192582  none                             none          1
# 2192583  none                      immigration          2
# 2192584  none                              cnn          3
# 2192585  none                             none          1
# 2192586  none                    racial issues         32
# 2192587  none                             none          2
# 2192588  none                             none          2
# 2192589  none                              cnn          1
# 2192590  none                             none          1
# 2192591  none                             none         10
# 2192592  none                 jobs and economy          1
# 2192593  none                             none          1
# 2192594   neg                             none          1
#
# [2192595 rows x 13 columns]

# %%
df4 = df3.groupby([df3['year'],df3['month'],df3['day'],df3['supports'],df3['Trump'],\
                   df3['Clinton'],df3['Sanders'],\
            df3['Cruz'],df3['Rubio'],df3['topic']]).sum().reset_index()

df4.head()
# Out:
#    year  month  day supports Trump Clinton Sanders  Cruz Rubio  \
# 0  2006      3   21     none  none    none    none  none  none
# 1  2006      3   30     none  none    none    none  none  none
# 2  2006      8   31     none   neu    none    none  none  none
# 3  2006      9    8     none  none    none    none  none  none
# 4  2006     12   22     none   neu    none    none  none  none
#
#                                   topic     index  hour  frequency
# 0                         racial issues   1987198    18          1
# 1                         racial issues   1319888    17          1
# 2                                  none   1901866    19          1
# 3  women's issues (not abortion though)   1354736    21          1
# 4                                  none  12567845   133          7

# %%
df4 = df4.drop('index', 1)
df4 = df4.drop('hour', 1)
df4
# Out:
#         year  month  day supports Trump Clinton Sanders  Cruz Rubio  \
# 0       2006      3   21     none  none    none    none  none  none
# 1       2006      3   30     none  none    none    none  none  none
# 2       2006      8   31     none   neu    none    none  none  none
# 3       2006      9    8     none  none    none    none  none  none
# 4       2006     12   22     none   neu    none    none  none  none
# 5       2007      5   12     none   neg    none    none  none  none
# 6       2007      8   24     none   neu    none    none  none  none
# 7       2008      1    9     none  none     neu    none  none  none
# 8       2008      1   10     none  none     neu    none  none  none
# 9       2008      2    9    Trump  none    none    none  none  none
# 10      2008      2   21     none  none     neu    none  none  none
# 11      2008      3    4     none  none     neg    none  none  none
# 12      2008      3    6     none  none     neu    none  none  none
# 13      2008      3   11     none  none     neu    none  none  none
# 14      2008      3   17     none  none     neu    none  none  none
# 15      2008      3   17     none  none     neu    none  none  none
# 16      2008      3   17     none  none     neu    none  none  none
# 17      2008      3   18     none  none    none    none  none   neu
# 18      2008      3   30     Cruz  none    none    none   neu  none
# 19      2008      5    6  Clinton  none     neg    none  none  none
# 20      2008      5    6     none  none     neu    none  none  none
# 21      2008      5    6     none  none     pos    none  none  none
# 22      2008      5   31     none  none     neu    none  none  none
# 23      2008      6    7     none  none     neu    none  none  none
# 24      2008      6    9    Trump  none     neg    none  none  none
# 25      2008      7   27     none  none    none     neg  none  none
# 26      2008      8   29    Trump   neg    none    none  none  none
# 27      2008      9   19     none  none    none    none  none  none
# 28      2008     10   15     none   neu    none    none  none  none
# 29      2008     10   24     none  none    none    none  none  none
# ...      ...    ...  ...      ...   ...     ...     ...   ...   ...
# 300196  2016      3   10     none   pos    none    none  none  none
# 300197  2016      3   10     none   pos    none    none  none  none
# 300198  2016      3   10     none   pos    none    none  none  none
# 300199  2016      3   10     none   pos    none    none  none  none
# 300200  2016      3   10     none   pos    none    none  none  none
# 300201  2016      3   10     none   pos    none    none  none  none
# 300202  2016      3   10     none   pos    none    none  none   pos
# 300203  2016      3   10     none   pos    none    none  none   pos
# 300204  2016      3   10     none   pos    none    none  none   pos
# 300205  2016      3   10     none   pos    none    none   pos   neg
# 300206  2016      3   10     none   pos    none    none   pos   neg
# 300207  2016      3   10     none   pos    none    none   pos   neu
# 300208  2016      3   10     none   pos    none    none   pos   neu
# 300209  2016      3   10     none   pos    none    none   pos  none
# 300210  2016      3   10     none   pos    none    none   pos  none
# 300211  2016      3   10     none   pos    none    none   pos  none
# 300212  2016      3   10     none   pos    none    none   pos  none
# 300213  2016      3   10     none   pos    none    none   pos  none
# 300214  2016      3   10     none   pos    none    none   pos  none
# 300215  2016      3   10     none   pos    none     pos  none  none
# 300216  2016      3   10     none   pos     pos     neg  none   neg
# 300217  2016      3   10     none   pos     pos     neg  none   neg
# 300218  2016      3   10     none   pos     pos     neg  none  none
# 300219  2016      3   10     none   pos     pos     neu   neu  none
# 300220  2016      3   10     none   pos     pos     neu  none  none
# 300221  2016      3   10     none   pos     pos     neu  none  none
# 300222  2016      3   10     none   pos     pos    none  none  none
# 300223  2016      3   10     none   pos     pos    none  none  none
# 300224  2016      3   10     none   pos     pos    none  none  none
# 300225  2016      3   10     none   pos     pos    none  none  none
#
#                                        topic  frequency
# 0                              racial issues          1
# 1                              racial issues          1
# 2                                       none          1
# 3       women's issues (not abortion though)          1
# 4                                       none          7
# 5                                       none          1
# 6                                       none          1
# 7                                       none          1
# 8                                       none          1
# 9                              racial issues          1
# 10                                     obama          1
# 11                                     obama          1
# 12                                      none          1
# 13                                      none          1
# 14                              bill clinton          1
# 15                                       cnn          1
# 16                                      iraq          1
# 17                                      none          1
# 18                                      none          1
# 19                                      none          1
# 20                                      none          1
# 21                             racial issues          3
# 22                                     obama          1
# 23                                      none          1
# 24                                     obama          1
# 25                                  abortion          1
# 26                                      none          1
# 27                    vice presidential pick          1
# 28                                      none          6
# 29                                     obama          1
# ...                                      ...        ...
# 300196                          ronaldreagan          2
# 300197                       social security         11
# 300198                             socialism          5
# 300199                                 syria          1
# 300200                              veterans         56
# 300201  women's issues (not abortion though)        289
# 300202                                   cnn          2
# 300203                                israel          1
# 300204                                  none         32
# 300205                                  isis          1
# 300206                                  none         11
# 300207                                   cnn          1
# 300208                                  none          4
# 300209                                   cnn          3
# 300210                fox news or moderators          4
# 300211                           immigration         21
# 300212                                  none        170
# 300213                              religion          3
# 300214  women's issues (not abortion though)          1
# 300215                                  none         15
# 300216                                   cnn          1
# 300217                                  none          2
# 300218                                  none         41
# 300219                                  none          1
# 300220                                   cnn          1
# 300221                                   gop          1
# 300222                              benghazi          1
# 300223                                   cnn          4
# 300224                fox news or moderators          1
# 300225                                  none         31
#
# [300226 rows x 11 columns]

# %%
df4.to_csv('daily_supports_results_scrubbed.csv')

# %%
# total = df2['frequency'].sum()
# print total

# with throwaway
# print total + 479103 #9172444

# %%
df4['frequency'].sum()
# Out:
# 63019564
