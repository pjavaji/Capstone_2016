# %%
#Debbie Hofman June 2016
#Read in our list of unique hashtags
#Look for hashtags that match our keywords

# %%
topic_keywords = [
'college',\
'marijuana',\
'flintwater',\
'familyleave',\
'clintonemails',\
'benghazi',\
'zika',\
'billclinton',\
'obama',\
'veterans',\
'torture',\
'homelandsecurity',\
'nationalsecurity',\
'socialsecurity',\
'socialism',\
'guncontrol',\
'healthcare',\
'cnn_news',\
'cnn_debate',\
'syria',\
'refugees',\
'iran',\
'iraq',\
'isis',\
'israel',\
'environment',\
'climate',\
'deathpenalty'
]

# %%
#open the .csv file with the set of all hashtags over the 40 days
import pandas as pd

htfile = pd.read_csv('hashtags_alldates.csv')
htfile.head()
# Out:
#        hashtag    count
# 0        trump  1864957
# 1    gopdebate  1681434
# 2  feelthebern  1432801
# 3    demdebate  1066694
# 4    trump2016  1038620

# %%
# Write out the hashtags that match the keywords in separate files, one per keyword.

httopic={}

for keyword in topic_keywords:
    
    df = htfile[htfile['hashtag'].str.contains(keyword)==True]
    df.to_csv('keywords/'+keyword+'.csv')

#outfile=topic_keywords[0] +'.csv' 
outfile='keywords/deathpenalty.csv'
# !cat $outfile
# Out:
# ,hashtag,count
# 1903,deathpenalty,1332
# 27654,endthedeathpenalty,34
# 34066,nodeathpenalty,25
# 69173,stopdeathpenalty,8
# 74845,abolishdeathpenalty,8
# 77592,abolishthedeathpenalty,7
# 80946,gaydeathpenalty,7
# 85547,enddeathpenalty,6
# 142641,antideathpenalty,3
# 179085,prodeathpenalty,2
# 199445,deathpenalty4obama,2
# 202027,killdeathpenalty,2
# 234812,saynotothedeathpenalty,1
# 242574,death2deathpenalty,1
# 317429,deathpenaltyismurderinginnocents,1
# 340673,deathpenaltycase,1
# 346118,savedeathpenalty,1
# 360458,deathpenaltystinkscuz,1
# 369485,nomoredeathpenalty,1
# 393716,abolishthedeathpenaltynow,1
# 415452,demsdeathpenalty,1
# 442104,yestodeathpenalty,1
# 491426,mandatedeathpenalty,1
# 491809,againstthedeathpenalty,1
# 494763,hillarydeathpenaltyclinton,1

# %%
# Create a set of selected hashtags (manually selected from files)

hts={}

hts['college']="""['freecollege','collegeforall','college4all','freecommunitycollege','tuitionfreecollege']"""
hts['marijuana']="""['marijuana','medicalmarijuana','legalizemarijuana','medicalmarijuanamovement']"""
hts['flintwater']="""['flintwater','flintwaterpoison','flintwaterworks']"""
hts['familyleave']=['paidfamilyleave','paidleave','parentalleave','voteleave','paidmaternityleave','familyleave']
hts['environment']=['environment','environmentalracism','environmentaljustice','climatechange','climate','actonclimate']
hts['clintonemails']=['clintonemails','hillaryclintonemails','clintonemailscandal']
hts['benghazi']=['benghazi','benghazimatters','benghazicommittee','benghazi4','rememberbenghazi',\
                 'hillarybenghaziclinton']
hts['zika']=['zika','zikavirus']
hts['billclinton']=['billclinton','movebillgetouttheway','arrestbillclinton','billary','billclintonrapes']
hts['obama']=['obama','thanksobama','barackobama','presidentobama','republicanobama']
hts['veterans']=['veterans','veteransfortrump','veterans4trump','veteransagainsttrump',\
                 'veteransforbernie']
hts['torture']=['torture','supporttorture','realtorture','tortureisawarcrime','stoptorture']
hts['homelandsecurity']=['bordersecurity','homelandsecurity','bordersecurityisnationalsecurity']
hts['socialsecurity']=['socialsecurity','savesocialsecurity','expandsocialsecurity']
hts['nationalsecurity']=['nationalsecurity','nationalsecurityfirst','nationalsecurityfail']
hts['socialism']=['socialism','socialismchecklist','democraticsocialism','socialismsucks','trysocialism','nosocialism']
hts['guncontrol']=['guncontrol','guncontrolnow','guncontrolkills']
hts['healthcare']=['obamacare','universalhealthcare','healthcareforall','healthcare4all','singlepayerhealthcare']
hts['cnn_news']=['cnn','cnn_news','cnnnews', 'cnnelection','cnnheadlines','cnnlive']
hts['cnn_debate']=['cnndebate','cnntownhall','cnngopdebate']
hts['syria']=['syria','syrian','syrians','dontbombsyria','syriac']
hts['refugees']=['syrianrefugees','nosyrianrefugees']
hts['iran']=['iran','irandeal','iranelections','stopexecutioniran','irantalks','noirandeal','nonucleariran']
hts['iraq']=['iraq','iraqwar','iraqi']
hts['isis']=['isis','noisis','stopisis']
hts['israel']=['israel','istandwithisrael','theisraelcompany','standwithisrael','israeltheregion','israeli','israelnews']
hts['deathpenalty']=['deathpenalty','endthedeathpenalty','nodeathpenalty','stopdeathpenalty','abolishdeathpenalty','abolishthedeathpenalty']

# %%
# now get tweets that contain the hashtags.

import csv

from neo4j.v1 import GraphDatabase, basic_auth

driver = GraphDatabase.driver("bolt://sauce5.sdsc.edu",auth=basic_auth("neo4j", "lajolla"))

query="""MATCH (t:Tweet_{0})<-[:TAGS]-(h:Hashtag_{0}) \
WHERE h.name in {1} and not exists(t.retweet_id) RETURN h.name, t.id_str, t.text LIMIT 200"""

partitions=['2016_3_1','2016_3_2','2016_3_3','2016_3_4','2016_3_5','2016_3_6','2016_3_7', '2016_3_8','2016_3_9', '2016_3_10']

df2 = pd.DataFrame()

with open('deathpenaltytweets.csv', 'wb') as csvfile:
    tweetwriter = csv.writer(csvfile)
    
    for partition in partitions:
        
        #for keyword in hts.keys():
        for keyword in ['deathpenalty']:

            query_formatted = query.format(partition,hts[keyword])
            print query_formatted

            session = driver.session()
            result = session.run(query_formatted)


            for record in result:
                print record
                tweetwriter.writerow([keyword,record[1].encode("utf-8"),record[2].encode("utf-8")])

            session.close()
# Out:
# MATCH (t:Tweet_2016_3_1)<-[:TAGS]-(h:Hashtag_2016_3_1) WHERE h.name in ['deathpenalty', 'endthedeathpenalty', 'nodeathpenalty', 'stopdeathpenalty', 'abolishdeathpenalty', 'abolishthedeathpenalty'] and not exists(t.retweet_id) RETURN h.name, t.id_str, t.text LIMIT 200
# <Record h.name=u'nodeathpenalty' t.id_str=u'704482080252698624' t.text=u'""Once in office, Bill Clinton made 60 new crimes eligible for the death penalty..." https://t.co/5dIv0idIoS #FuckTheClintons #NoDeathPenalty "'>
# <Record h.name=u'deathpenalty' t.id_str=u'704816498871836672' t.text=u'"Things I\'ll never understand about the US #guns #deathpenalty &amp; #Trump ??? \U0001f1fa\U0001f1f8 "'>
# <Record h.name=u'deathpenalty' t.id_str=u'685018217358716928' t.text=u'"#tbt 1989 \u27a1 Trump wants the #deathpenalty for teenagers! You can\'t #bringback the dead! #centralpark5 #DNA #NYC https://t.co/M5iAXO85jm "'>
# <Record h.name=u'deathpenalty' t.id_str=u'704755725021671424' t.text=u'"#Utah State @SenatorSteveU now sees #deathpenalty as inefficient, costly, &amp; wrong. https://t.co/7tKTsb1ide @DPInfoCtr @CCATDP @CPAC "'>
# <Record h.name=u'deathpenalty' t.id_str=u'704752044800921600' t.text=u'"The @washingtonpost\'s The Fix interviewed @SenatorSteveU [Urquhart] re his #deathpenalty views. https://t.co/euUc6yWlLl @DPInfoCtr @CCATDP "'>
# <Record h.name=u'deathpenalty' t.id_str=u'
'>
# <Record h.name=u'deathpenalty' t.id_str=u'705099342290526208' t.text=u'"Republican Senator Urquhart in Utah introduces bill to replace #deathpenalty, clears first vote in Senate 20-9 https://t.co/3u9fP5A8sZ "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705098148494979072' t.text=u'"Tell California to leave executions in the past \u2013 where they belong! https://t.co/lV7oiJZL2V #deathpenalty https://t.co/qRjQ6UkosI "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705070240040882176' t.text=u'"Senate Democrats are lining up in support @SayfieReview @FlaDems #deathpenalty  https://t.co/J7ch5cAsWN "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705055904157327361' t.text=u'"On FL Senate floor Senate Dems lining up in support of @ClemensFL amendment requiring unanimous jury vote in #deathpenalty verdicts. #sayfie "'>
# <Record h.name=u'deathpenalty' t.id_str=u'704752044800921600' t.text=u'"The @washingtonpost\'s The Fix interviewed @SenatorSteveU [Urquhart] re his #deathpenalty views. https://t.co/euUc6yWlLl @DPInfoCtr @CCATDP "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705010183915724800' t.text=u'"@ArchStanton13 @HillaryClinton  @Pontifex calls it a #DeathPenalty Pls sign &amp; rt to ask @POTUS to#EndLWOP https://t.co/NGLEUzdwZA "'>
# <Record h.name=u'deathpenalty' t.id_str=u'685018217358716928' t.text=u'"#tbt 1989 \u27a1 Trump wants the #deathpenalty for teenagers! You can\'t #bringback the dead! #centralpark5 #DNA #NYC https://t.co/M5iAXO85jm "'>
# <Record h.name=u'deathpenalty' t.id_str=u'704819361446383617' t.text=u'"@HillaryGuess @docholly Pope has called on his Faithful to work towards the Abolishment of #DeathPenalty ... Bernie\'s Anti #DeathPenalty ... "'>
# <Record h.name=u'deathpenalty' t.id_str=u'704819901832105986' t.text=u'"@HillaryGuess @docholly #WhichHillary &amp; All Major Candidates (Except Bernie) Are Pro #DeathPenalty .. (I See #Catholic Votes) #FeelTheBern "'>
# <Record h.name=u'nodeathpenalty' t.id_str=u'705095561905467392' t.text=u'"Econ&amp;social justice issues animate the Sanders campaign  Hillary says #Justice is a single issue platform, well OK :-)  #NoDeathPenalty "'>
# MATCH (t:Tweet_2016_3_3)<-[:TAGS]-(h:Hashtag_2016_3_3) WHERE h.name in ['deathpenalty', 'endthedeathpenalty', 'nodeathpenalty', 'stopdeathpenalty', 'abolishdeathpenalty', 'abolishthedeathpenalty'] and not exists(t.retweet_id) RETURN h.name, t.id_str, t.text LIMIT 200
# <Record h.name=u'deathpenalty' t.id_str=u'705520068516515840' t.text=u'"#Republican support aids passage of #deathpenalty repeal bill through Utah Senate; House is next! Go, #UtLeg!... https://t.co/a9jhJHCii4 "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705495770552778753' t.text=u'"Like most of USA\' #deathpenalty due to wealthy #KKK ALEC #GOP merely EXECUTING Minorities with fabricated racist BS  https://t.co/ulx4itqq1h "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705494071507292161' t.text=u'"Sen Republicans in UT vote 15-12 to end the #deathpenalty because its costly, risks the innocent, and cheapens life https://t.co/DUA3z0LGHU "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705490448001859584' t.text=u'"@MsRock4Ever Getting interesting as #BernieSanders now getting into #FreeTrade issues in #Detroit &amp; Pope has decried #Global #DeathPenalty "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705466303415492609' t.text=u'"Sen Republicans in UT vote 15-12 to end the #deathpenalty because its costly, risks the innocent, and cheapens life https://t.co/ws6hGZFDWZ "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705456715374817282' t.text=u'""The #deathpenalty risks innocent lives. I know\u201d -Juan Melendez https://t.co/LnjOEXmi72 https://t.co/ukxmnt4Tz7 "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705452449268502530' t.text=u'"Sen Republicans in UT vote 15-12 to end the #deathpenalty because it\'s costly, risks the innocent, and cheapens life https://t.co/bg3qdN7wXb "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705451162082869249' t.text=u'"Sen Republicans in UT vote 15-12 to end the #deathpenalty because it "cheapens life" https://t.co/fbFnEy4r25 "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705447042873696257' t.text=u'"Sen #Republicans in #Utah just voted 15-12 to end #deathpenalty b/c it\'s costly, risks the innocent &amp; cheapens life https://t.co/Vi1BdLSJaB "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705112318988804096' t.text=u'"Utah Senate passes bill to repeal the #deathpenalty 15-12. Bill heads to house. #UTRepeal #utpol "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705391082696216576' t.text=u'"RT @dpinfoctr: NEW VOICES: Republican Former #DeathPenalty Supporter Leads Repeal Effort in #Utah. https://t.co/gcP0Yoxb2E "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705280768071835652' t.text=u'"#ImWithHer ppl, do you want a #bloodthirsty leader? #Hillary supports #deathpenalty. The gov is NOT GOD, shouldn\'t take lives. #FeelTheBern "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705232444010549248' t.text=u'"@TotalCatholic @CatholicsFollow (An IMPORTANT reason to Organize for #BernieSanders ..Opponent of #DeathPenalty ) &gt;&gt; https://t.co/pNWnr6d6Cf "'>
# MATCH (t:Tweet_2016_3_4)<-[:TAGS]-(h:Hashtag_2016_3_4) WHERE h.name in ['deathpenalty', 'endthedeathpenalty', 'nodeathpenalty', 'stopdeathpenalty', 'abolishdeathpenalty', 'abolishthedeathpenalty'] and not exists(t.retweet_id) RETURN h.name, t.id_str, t.text LIMIT 200
# <Record h.name=u'deathpenalty' t.id_str=u'705848280995921920' t.text=u'"RT:  wow! injustice vote to keep #deathpenalty!  @BernieSanders wants to end it this cruel &amp; unusual punishment! https://t.co/eNAcD5R5bu "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705846286751109120' t.text=u'"DE voted to keep the #deathpenalty a week after apologizing for slavery. Tell them what you think of the hypocrisy: https://t.co/vcu5dpaHfH "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705828650927546369' t.text=u'"@ND4Bernie @People4Bernie @BernieSanders @WPJohnWagner Remember the #Pope #DeathPenalty msg? Phonebank #Catholic &amp;Parishes = Bernie VOTES!! "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705820096128614400' t.text=u'"@Deir_in_DC @MSNBC @HillaryClinton This is Where #Pope New Global drive against #DeathPenalty May help #BernieSanders Immensely #FeelTheBern "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705796478049001472' t.text=u'"@ChefLarryEdward @NCForBernie @Rich_fxdump @BernieSanders This is where Pope\'s New Drive against the #DeathPenalty may be Key! #FeelTheBern "'>
# <Record h.name=u'deathpenalty' t.id_str=u'702326762101813250' t.text=u'"Don\'t EVER forget: Hillary for: #IraqWar, #DeathPenalty, #PrivatePrisons, #TPP, #KeystoneXL Hillary against: #SameSexMarriage + #DemTownHall "'>
# <Record h.name=u'deathpenalty' t.id_str=u'675672913782046720' t.text=u'"#DonaldTrump #YourPotus Death Penalty for Cop Killers ! #Cops #FBI #LawEnforcement #NSA #Police #DeathPenalty #Trump https://t.co/VL1nigeJRN "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705105266673635328' t.text=u'"Ending the cruel, unjust &amp; discriminatory #DeathPenalty: If not now, when? https://t.co/Hl72Kjj2Cd #USA https://t.co/c8UhJaLoMp "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705615062019387392' t.text=u'"#deathpenalty #DeathRow #billclinton#hillary #innocence #murder by #Clintons https://t.co/slAFWaEhmw "'>
# <Record h.name=u'deathpenalty' t.id_str=u'705466303415492609' t.text=u'"Sen Republicans in UT vote 15-12 to end the #deathpenalty because its costly, risks the innocent, and cheapens life https://t.co/ws6hGZFDWZ "'>
# MATCH (t:Tweet_2016_3_5)<-[:TAGS]-(h:Hashtag_2016_3_5) WHERE h.name in ['deathpenalty', 'endthedeathpenalty', 'nodeathpenalty', 'stopdeathpenalty', 'abolishdeathpenalty', 'abolishthedeathpenalty'] and not exists(t.retweet_id) RETURN h.name, t.id_str, t.text LIMIT 200
# <Record h.name=u'deathpenalty' t.id_str=u'706194667176497152' t.text=u'"On the #deathpenalty. Which #Democrat sides more with the base? #CapitalPunishment #Bernie2016 #BernieorBust https://t.co/K0SVCO57bG "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706053503685369856' t.text=u'"@HillaryClinton never met a war she didnt like. She stands with the #NRA #Monsanto &amp; the #deathpenalty Please get honest, she\'s a #Murderer "'>
# <Record h.name=u'deathpenalty' t.id_str=u'
'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662635274567680' t.text=u'"At #DemDebate #BernieSanders Opposes #deathPenalty &amp; #massIncarceration. Me too. #DebateWithBernie "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662860945018880' t.text=u'"@BernieSanders is the only candidate from either party that opposes #deathpenalty. #DemDebate "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662507641905152' t.text=u'"As a #progressive #Democrat this is a biggie for me. @BernieSanders opposes #DeathPenalty &amp; has my #vote. #DemDebate https://t.co/o0FxivwauU "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662485659496449' t.text=u'"In 1996, 71% of Democrats supported #deathpenalty; today, 40%. Rep support more enduring (87% v 77%) #DemDebate https://t.co/FsaYLTQev5 "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662482753011712' t.text=u'"#BernieSanders against #deathpenalty says less people will be in prison by the end of his term #CNNDebate "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662449475403776' t.text=u'"@FoxNews @SenSanders @HillaryClinton Holdthe animal who uses a weapon in mass killing to the full extent of the law #DeathPenalty #DemDebate "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662386812526592' t.text=u'"Sanders dropping some adult knowledge. #deathpenalty #assaultweapons #massincarceration "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662294118232065' t.text=u'"#Sanders just said he is and always has been against the #deathpenalty. I love this man. #FeelTheBern #DemDebate "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662273134284800' t.text=u'"@BernieSanders opposes #DeathPenalty and I trust that he will decrease the number of people we incarcerate in USA #Bernie #BlackLivesMatter "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662118058270721' t.text=u'"#Bernie mentions opposition to #deathpenalty, which is major difference between him &amp; #Hillary. #DemDebate "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706600661228634112' t.text=u'"Republican Utah State Senator Urquhart once supported the #deathpenalty; now, he\'s leading the #UT abolition effort https://t.co/GLLNBkP3yF "'>
# MATCH (t:Tweet_2016_3_8)<-[:TAGS]-(h:Hashtag_2016_3_8) WHERE h.name in ['deathpenalty', 'endthedeathpenalty', 'nodeathpenalty', 'stopdeathpenalty', 'abolishdeathpenalty', 'abolishthedeathpenalty'] and not exists(t.retweet_id) RETURN h.name, t.id_str, t.text LIMIT 200
# <Record h.name=u'deathpenalty' t.id_str=u'707333579085193217' t.text=u'"What happens to CA\'s behemoth #deathpenalty system will undoubtedly affect the whole U.S.: https://t.co/lV7oiJZL2V https://t.co/qRjQ6UkosI "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707318257619832832' t.text=u'"A death for a death solves nothing https://t.co/Zgo7fzgC4S #deathpenalty #TrueJusticeIsHealing "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707306908005179392' t.text=u'"Conservatives Ensure The #DeathPenalty\u2019s Inevitable End: https://t.co/BV1eiFu2FZ by @CCATDP "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707295751035031552' t.text=u'"SB189, a bill which would abolish the #deathpenalty in #Utah, passed the State Senate in a preliminary vote https://t.co/sWkXTmW3ZW "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707291552083607552' t.text=u'"Pope again calls for worldwide ban on #deathpenalty: https://t.co/MNMExw6vAF https://t.co/umb3RBh64y "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706662485659496449' t.text=u'"In 1996, 71% of Democrats supported #deathpenalty; today, 40%. Rep support more enduring (87% v 77%) #DemDebate https://t.co/FsaYLTQev5 "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707265323699970048' t.text=u'"@DailyCaller on #Republican support for #deathpenalty repeal in Utah:  "Further, conservatives who value life are... https://t.co/9pkmL5q6Vv "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707208523440992256' t.text=u'"#Undecideds Join #NotMeUs Help Ban #Fracking Abolish #DeathPenalty #FightFor15 Support #BLM #Michigan We Need You  https://t.co/uUnW5cQWV2 "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707163288149364740' t.text=u'"Under @BernieSanders leadership we will be closer to getting out of killing biz #drone #deathpenalty @PFADPofNC  https://t.co/OxpkNUOiIJ "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707105546470555649' t.text=u'"@BernieSanders And why the @coe does, too. #deathpenalty #capitalpunishment #abolishthedeathpenalty #abolishcapitalpunishment "'>
# <Record h.name=u'deathpenalty' t.id_str=u'
'>
# <Record h.name=u'deathpenalty' t.id_str=u'707373171146678273' t.text=u'"Hillary\'s race/gender identity voters appear to be the single issue voters in this race. #fracking #deathpenalty #incomeequality #TPP #NAFTA "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707365008435339264' t.text=u'"UT Committee is moving fast. According to agenda, #deathpenalty repeal #sb189 is next. "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707356511178199040' t.text=u'"Learn more about the #deathpenalty tonight at 8p EST as @Diannatncadp talks with @AJCRadio #haltallexecutions https://t.co/uGRII3oYzP "'>
# MATCH (t:Tweet_2016_3_10)<-[:TAGS]-(h:Hashtag_2016_3_10) WHERE h.name in ['deathpenalty', 'endthedeathpenalty', 'nodeathpenalty', 'stopdeathpenalty', 'abolishdeathpenalty', 'abolishthedeathpenalty'] and not exists(t.retweet_id) RETURN h.name, t.id_str, t.text LIMIT 200
# <Record h.name=u'deathpenalty' t.id_str=u'708069510658400256' t.text=u'"@HillaryClinton @JusticeWorksAct in our campaign to end the #DeathPenalty and save innocent people like Ricky: https://t.co/1GaCFG5KEn "'>
# <Record h.name=u'deathpenalty' t.id_str=u'708065315121303552' t.text=u'"#Hillary is FOR the #DeathPenalty  #Bernie Sanders is against it. Glad this wrongly convicted man is still alive. https://t.co/ssHMpEWLQm "'>
# <Record h.name=u'deathpenalty' t.id_str=u'708022941771022336' t.text=u'"Rep Ray says a lot of things about #DeathPenalty, such as: "This is the one true deterrent" He\'s often wrong #utpol https://t.co/6xwBxjy8JK "'>
# <Record h.name=u'deathpenalty' t.id_str=u'708014874496991232' t.text=u'"ALL victims\' families? There r diff opinions among victims re: #DeathPenalty (see also: David&amp;Steven Shapiro) #utpol https://t.co/xIJkVzgQzn "'>
# <Record h.name=u'deathpenalty' t.id_str=u'708013276915998721' t.text=u'"Maybe there will be a last minute exoneration? #DeathPenalty inspires a lot of those, as we well know. #utpol https://t.co/HE8ylUdGPG "'>
# <Record h.name=u'deathpenalty' t.id_str=u'708012546679132161' t.text=u'"The #DeathPenalty bill was just taken OFF the agenda in the House GOP Caucus. Bill could be dead. #utpol "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707941344363225088' t.text=u'"Utah prosecutor: I put people on death row, and I know it\'s time to end the #deathpenalty https://t.co/v45mNMSWv1 via @sltrib "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707722158039023616' t.text=u'"The #DeathPenalty goes against everything conservatives stand for.  #TCOT #TLOT #UTLEG https://t.co/UUr4VWTdLc "'>
# <Record h.name=u'deathpenalty' t.id_str=u'706600661228634112' t.text=u'"Republican Utah State Senator Urquhart once supported the #deathpenalty; now, he\'s leading the #UT abolition effort https://t.co/GLLNBkP3yF "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707721194544365568' t.text=u'"GOP lawmakers in Utah expected to ban the #DeathPenalty. That\'s great news from a conservative perspective: https://t.co/o8m1im0FSO #TCOT "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707679834462232577' t.text=u'"GOP repeal sponsor tells #deathpenalty proponents "The death penalty you support is not the death penalty we have." @DPInfoCtr "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707706970996940801' t.text=u'"What things will #Hillary get done?  #SinglePayer? No. #BanFracking? No. #FightFor15? No. Oppose #DeathPenalty? No.  #FeelTheBern "'>
# <Record h.name=u'deathpenalty' t.id_str=u'707702622589992962' t.text=u'".@BernieSanders thank you for standing against #DeathPenalty, please stand with us against drone strikes as well. https://t.co/7PIJ0rnLGO "'>
